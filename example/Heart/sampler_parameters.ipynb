# %% [markdown]
# # Experiment: Comparing different sampling parameters for training

# %%
using Revise, QARBoM, DWave, DataFrames, CSV

# %%
MOI = QARBoM.QUBO.ToQUBO.MOI
# Out:
# MathOptInterface

# %%
df = DataFrame(CSV.File(raw"./converted_bool_only.csv"))

x_train = Vector{Vector{Int}}()

for row in eachrow(df)
    push!(x_train, collect(row))
end

# %%
learning_rate = 0.0002
# Out:
# 0.0002

# %%
num_sweeps = [i for i in 1:25:101]
num_reads = [i for i in 1:25:101]
# Out:
# 5-element Vector{Int64}:
#    1
#   26
#   51
#   76
#  101

# %%
W = randn(22,10)
# Out:
# 22×10 Matrix{Float64}:
#  -0.216505   -0.765594    1.28173   …   0.45392    0.38484     -0.615173
#   0.345152   -1.12937     0.541348     -0.18382   -0.672884    -1.71366
#  -0.439022   -0.761079   -1.31743      -0.475569  -0.0731931   -0.314445
#   1.39857    -0.513349   -0.863664      0.383678  -0.391906    -0.795293
#  -0.713223   -0.868238   -0.24816      -0.212508   1.27777      0.156998
#   1.05306     0.470819   -2.15005   …  -0.774081   1.53349     -0.113756
#   0.425849    0.765588    0.024888      0.574296  -0.330341     0.669741
#  -1.1631     -1.27941     0.492526     -0.592812  -0.00362266  -1.21985
#   0.974727   -0.835029    0.545166      1.31181    0.229642     1.61809
#   1.37342     1.22238    -1.06174      -0.385003   0.271793     1.03826
#   0.463458    0.482911   -0.431246  …  -0.161528   1.72504      0.864121
#   0.0699086  -0.0543774  -0.493776     -0.959612   0.666959    -0.217816
#  -0.38154     0.628583    0.805866     -0.261545   0.935392     0.336466
#  -0.823389    1.23848    -1.13504       0.651343   0.588076     0.130486
#   0.588418   -1.00939    -0.557815      0.236787   0.0539614    0.594157
#   0.0897145  -0.672078    1.01135   …  -0.18092   -1.38098     -1.24983
#   0.659305    1.57448     0.422427      0.154027   1.54225     -0.687436
#  -0.648095   -1.10577     1.06748       1.80279    1.45722      0.214156
#   0.644253    0.300402   -0.224047      1.43991   -0.210604    -1.60129
#  -0.153241   -0.170748   -0.790809     -1.10382    0.619059     0.44142
#  -0.298134   -0.154816   -1.88728   …   0.681128   0.603084     1.90013
#  -0.350577   -0.254299    1.19125       0.222679   1.47479     -1.66744

# %%
all_mse = []
times = Vector{Float64}()
# Out:
# Float64[]

# %%
MOI.supports(::DWave.Neal.Optimizer, ::MOI.ObjectiveSense) = true

# %%
for nr in num_reads
    for ns in num_sweeps
        rbm = RBM(22,10, W)

        function setup_dwave(model, sampler)
            MOI.set(model, MOI.RawOptimizerAttribute("num_reads"), nr)
            MOI.set(model, MOI.RawOptimizerAttribute("num_sweeps"), ns)
        end
    
        println()
        println("Reads $(nr) | Sweeps $(ns)") 
        println()

        t = time()
    
        mse = QARBoM.train_persistent_qubo!(
            rbm, 
            x_train[1:10000];
            batch_size = 10, 
            n_epochs = 50,  
            learning_rate = [learning_rate for i in 1:50],
            model_setup = setup_dwave,
            sampler = DWave.Neal.Optimizer
        )
    
        push!(times, time() -t)
        push!(all_mse, mse)
    end
end
# Out:
# Reads 1 | Sweeps 1
#
# Setting up QUBO model
# Setting mini-batches
# Starting training
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |
|
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    39 |    1.9690 |        0.0121 |       8.4431 |        1.2279 |  393.4938 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    40 |    1.9669 |        0.0119 |       8.2009 |        1.3281 |  403.0347 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    41 |    1.9638 |        0.0120 |       8.3646 |        1.2644 |  412.6756 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    42 |    1.9578 |        0.0653 |       8.8713 |        1.2569 |  422.8691 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    43 |    1.9507 |        0.0120 |       9.0313 |        1.2512 |  433.1637 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    44 |    1.9449 |        0.0122 |       9.1947 |        1.2815 |  443.6521 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    45 |    1.9408 |        0.0121 |       8.9396 |        1.3490 |  453.9528 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    46 |    1.9374 |        0.0119 |       8.6601 |        1.2925 |  463.9174 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    47 |    1.9360 |        0.0119 |       8.9953 |        1.2206 |  474.1452 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    48 |    1.9352 |        0.0144 |      11.5228 |        1.4376 |  487.1200 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    49 |    1.9339 |        0.0688 |       9.5101 |        1.2016 |  497.9005 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    50 |    1.9326 |        0.0120 |       9.2684 |        1.2168 |  508.3977 |
# |------------------------------------------------------------------------------|
# Finished training after 50 epochs.
# Total time spent sampling: 1.1200366020202637
# Total time spent in Quantum sampling: 444.3631238937378
# Total time spent updating parameters: 62.91452717781067
# Total time spent training: 508.3976876735687

# %%
df = DataFrame()
i = 1
for nr in num_reads
    for ns in num_sweeps
        df[!,"r_$(nr)_s_$(ns)"] =  all_mse[i]
        i += 1
    end
end
df
# Out:
# 50×25 DataFrame
#  Row │ r_1_s_1  r_1_s_26  r_1_s_51  r_1_s_76  r_1_s_101  r_26_s_1  r_26_s_26   ⋯
#      │ Float64  Float64   Float64   Float64   Float64    Float64   Float64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 7.2888    7.03752   7.04563   7.0526     7.051     7.28749    7.02651   ⋯
#    2 │ 5.97852   5.38069   5.40335   5.41236    5.41446   5.97611    5.36003
#    3 │ 5.01713   4.18229   4.19616   4.20641    4.20466   5.04079    4.19114
#    4 │ 4.34916   3.45759   3.46613   3.47573    3.47669   4.40346    3.52484
#    5 │ 3.89132   3.04271   3.0525    3.06036    3.06259   3.96376    3.15107   ⋯
#    6 │ 3.58056   2.77788   2.79866   2.80493    2.80865   3.6537     2.91395
#    7 │ 3.34215   2.60644   2.62475   2.6296     2.63482   3.43825    2.74593
#    8 │ 3.17788   2.47644   2.49196   2.49811    2.5019    3.28142    2.61318
#    9 │ 3.0476    2.38706   2.39832   2.40384    2.40768   3.16965    2.49278   ⋯
#   10 │ 2.9628    2.3226    2.33238   2.33774    2.34212   3.0871     2.3862
#   11 │ 2.89461   2.27704   2.28464   2.28919    2.2924    3.02108    2.3099
#   ⋮  │    ⋮        ⋮         ⋮         ⋮          ⋮         ⋮          ⋮       ⋱
#   41 │ 2.39764   2.28994   2.29779   2.30083    2.30771   2.6388     1.97353
#   42 │ 2.4027    2.30041   2.30862   2.31126    2.31626   2.63802    1.96946   ⋯
#   43 │ 2.40595   2.31039   2.31768   2.32289    2.32692   2.6341     1.96539
#   44 │ 2.40669   2.32278   2.32834   2.33456    2.33774   2.63115    1.96223
#   45 │ 2.41099   2.33346   2.33894   2.34464    2.34953   2.62846    1.95923
#   46 │ 2.41481   2.3447    2.35245   2.35578    2.36217   2.62555    1.95501   ⋯
#   47 │ 2.42718   2.35568   2.36473   2.36752    2.37404   2.62101    1.95125
#   48 │ 2.42909   2.36821   2.37664   2.38105    2.38528   2.61807    1.94758
#   49 │ 2.43195   2.38081   2.38894   2.39451    2.39589   2.61393    1.94295
#   50 │ 2.4343    2.39261   2.40127   2.40631    2.408     2.61153    1.93974   ⋯
#                                                   18 columns and 29 rows omitted

# %%
CSV.write("benchmark_dwave_parameters.csv", df)
# Out:
# "benchmark_dwave_parameters.csv"

# %%
using Plots

# %%
df_loaded = DataFrame(CSV.File("benchmark_dwave_parameters.csv"))
# Out:
# 50×25 DataFrame
#  Row │ r_1_s_1  r_1_s_26  r_1_s_51  r_1_s_76  r_1_s_101  r_26_s_1  r_26_s_26   ⋯
#      │ Float64  Float64   Float64   Float64   Float64    Float64   Float64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 7.2888    7.03752   7.04563   7.0526     7.051     7.28749    7.02651   ⋯
#    2 │ 5.97852   5.38069   5.40335   5.41236    5.41446   5.97611    5.36003
#    3 │ 5.01713   4.18229   4.19616   4.20641    4.20466   5.04079    4.19114
#    4 │ 4.34916   3.45759   3.46613   3.47573    3.47669   4.40346    3.52484
#    5 │ 3.89132   3.04271   3.0525    3.06036    3.06259   3.96376    3.15107   ⋯
#    6 │ 3.58056   2.77788   2.79866   2.80493    2.80865   3.6537     2.91395
#    7 │ 3.34215   2.60644   2.62475   2.6296     2.63482   3.43825    2.74593
#    8 │ 3.17788   2.47644   2.49196   2.49811    2.5019    3.28142    2.61318
#    9 │ 3.0476    2.38706   2.39832   2.40384    2.40768   3.16965    2.49278   ⋯
#   10 │ 2.9628    2.3226    2.33238   2.33774    2.34212   3.0871     2.3862
#   11 │ 2.89461   2.27704   2.28464   2.28919    2.2924    3.02108    2.3099
#   ⋮  │    ⋮        ⋮         ⋮         ⋮          ⋮         ⋮          ⋮       ⋱
#   41 │ 2.39764   2.28994   2.29779   2.30083    2.30771   2.6388     1.97353
#   42 │ 2.4027    2.30041   2.30862   2.31126    2.31626   2.63802    1.96946   ⋯
#   43 │ 2.40595   2.31039   2.31768   2.32289    2.32692   2.6341     1.96539
#   44 │ 2.40669   2.32278   2.32834   2.33456    2.33774   2.63115    1.96223
#   45 │ 2.41099   2.33346   2.33894   2.34464    2.34953   2.62846    1.95923
#   46 │ 2.41481   2.3447    2.35245   2.35578    2.36217   2.62555    1.95501   ⋯
#   47 │ 2.42718   2.35568   2.36473   2.36752    2.37404   2.62101    1.95125
#   48 │ 2.42909   2.36821   2.37664   2.38105    2.38528   2.61807    1.94758
#   49 │ 2.43195   2.38081   2.38894   2.39451    2.39589   2.61393    1.94295
#   50 │ 2.4343    2.39261   2.40127   2.40631    2.408     2.61153    1.93974   ⋯
#                                                   18 columns and 29 rows omitted

# %%
df_loaded[1,"r_1_s_1"]
# Out:
# 7.28880148213567

# %%
keys_to_remove = []
for key in names(df_loaded)
    if df_loaded[50, key] > 1.95
        push!(keys_to_remove, key)
    end
end

# %%
# df_to_plot = select!(df_loaded, Not(["0.0005", "0.0007", "0.0008", "0.0009", "0.001"]))
df_to_plot = select!(df_loaded, Not(keys_to_remove))
# df_to_plot = df_loaded
# Out:
# 50×9 DataFrame
#  Row │ r_26_s_26  r_26_s_51  r_26_s_76  r_26_s_101  r_51_s_76  r_51_s_101  r_7 ⋯
#      │ Float64    Float64    Float64    Float64     Float64    Float64     Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   7.02651    7.02826    7.02849     7.02877    7.02738     7.02769    7 ⋯
#    2 │   5.36003    5.3717     5.37437     5.37698    5.36997     5.37365    5
#    3 │   4.19114    4.1964     4.19737     4.20043    4.2003      4.20232    4
#    4 │   3.52484    3.50925    3.50351     3.50204    3.52062     3.5137     3
#    5 │   3.15107    3.11808    3.10214     3.09494    3.13913     3.12258    3 ⋯
#    6 │   2.91395    2.88438    2.86391     2.85635    2.91687     2.89808    2
#    7 │   2.74593    2.70364    2.6859      2.67739    2.74012     2.72468    2
#    8 │   2.61318    2.56049    2.5494      2.53901    2.59035     2.58245    2
#    9 │   2.49278    2.43645    2.42567     2.41728    2.46294     2.45189    2 ⋯
#   10 │   2.3862     2.33391    2.32348     2.32041    2.35448     2.3445     2
#   11 │   2.3099     2.26245    2.25537     2.252      2.28017     2.27237    2
#   ⋮  │     ⋮          ⋮          ⋮          ⋮           ⋮          ⋮           ⋱
#   41 │   1.97353    1.94157    1.92812     1.91425    1.95018     1.93999    1
#   42 │   1.96946    1.94086    1.92647     1.91108    1.94685     1.93783    1 ⋯
#   43 │   1.96539    1.93976    1.9243      1.90802    1.94331     1.93586    1
#   44 │   1.96223    1.93816    1.92141     1.90468    1.93971     1.93408    1
#   45 │   1.95923    1.93541    1.91897     1.90247    1.93655     1.93127    1
#   46 │   1.95501    1.93194    1.91515     1.90017    1.93467     1.9275     1 ⋯
#   47 │   1.95125    1.92803    1.91142     1.89758    1.93337     1.92351    1
#   48 │   1.94758    1.92503    1.90733     1.89566    1.9314      1.92044    1
#   49 │   1.94295    1.92113    1.90327     1.89379    1.9291      1.91696    1
#   50 │   1.93974    1.9177     1.89904     1.89001    1.92675     1.91366    1 ⋯
#                                                    3 columns and 29 rows omitted

# %%
plot(Matrix(df_to_plot), labels=permutedims(string.(names(df_to_plot))), linewidth=2, botton_margin=0, right_margin = 3Plots.mm)
# plot(range(1,50, length = 50), all_mse[2],label = "ϵ = 0.002")
theme(:wong)


lens!([49, 50], [1.88, 1.95], inset = (1, bbox(0.5, 0.0, 0.4, 0.4)), subplot=2)


xlabel!("Epoch", subplot =1)
ylabel!("Mean Squared Error", subplot =1 )

plot!(legend=:outerbottom, legendcolumns=3)

savefig("errors.pdf")
# Out:
# "/Users/pripper/Documents/GitHub/RBM/example/Heart/errors.pdf"
