# %%
using Revise, QARBoM, DWave, DataFrames, CSV
# Out:
# [ Info: Precompiling DWave [4d534982-bf11-4157-9e48-fe3a62208a50]
#     CondaPkg Found dependencies: C:\Users\pedroripper\.julia\packages\DWave\i51VN\CondaPkg.toml
#     CondaPkg Found dependencies: C:\Users\pedroripper\.julia\packages\PythonCall\S5MOg\CondaPkg.toml
#     CondaPkg Found dependencies: C:\Users\pedroripper\.julia\packages\DWave\Ui1Yj\CondaPkg.toml
#     CondaPkg Resolving changes
#              - libstdcxx-ng
#     CondaPkg Removing environment
#              │ C:\Users\pedroripper\.julia\artifacts\cba433181fa6470b206db49415f1b7593a9d25ff\bin\micromamba.exe
#              │ -r C:\Users\pedroripper\.julia\scratchspaces\0b3b1443-0f03-428d-bdfb-f27f9c1191ea\root
#              │ remove
#              │ -y
#              │ -p D:\git\RBM\example\.CondaPkg\env
#              └ --all
# Transaction
#
#   Prefix: D:\git\RBM\example\.CondaPkg\env
#
#   Removing specs:
#
#    - _libgcc_mutex
#    - _openmp_mutex
#    - bzip2
#    - ca-certificates
#    - ld_impl_linux-64
#    - libffi
#    - libgcc-ng
#    - libgomp
#    - libsqlite
#    - libstdcxx-ng
#    - libuuid
#    - libzlib
#    - ncurses
#    - openssl
#    - pip
#    - python
#    - readline
#    - setuptools
#    - sqlite
#    - tk
#    - tzdata
#    - wheel
#    - xz
#    - zlib
#
#
#   Package              Version  Build               Channel           Size
# ----------------------------------------------------------------------------
#   Remove:
# ----------------------------------------------------------------------------
#
#   - pip                   24.0  pyhd8ed1ab_0        conda-forge     Cached
#   - python              3.11.0  h7a1cb2a_3          anaconda          36MB
#   - setuptools          70.0.0  pyhd8ed1ab_0        conda-forge     Cached
#   - wheel               0.43.0  pyhd8ed1ab_1        conda-forge     Cached
#   - zlib                1.2.13  h4ab18f5_6          conda-forge       93kB
#   - xz                   5.4.2  h5eee18b_0          anaconda         764kB
#   - tzdata               2024a  h0c530f3_0          conda-forge     Cached
#   - tk                  8.6.13  noxft_h4845f30_101  conda-forge        3MB
#   - sqlite              3.45.3  h2c6b66d_0          conda-forge      849kB
#   - openssl             1.1.1w  h7f8727e_0          anaconda           4MB
#   - libuuid             1.41.5  h5eee18b_0          anaconda          29kB
#   - libffi               3.4.4  h6a678d5_0          anaconda         148kB
#   - ld_impl_linux-64      2.40  hf3520f5_2          conda-forge      708kB
#   - bzip2                1.0.8  hd590300_5          conda-forge      254kB
#   - readline               8.2  h8228510_1          conda-forge      281kB
#   - libsqlite           3.45.3  h2797004_0          conda-forge      860kB
#   - ca-certificates   2024.6.2  hbcca054_0          conda-forge      156kB
#   - libstdcxx-ng        12.3.0  hc0a3c3a_7          conda-forge        3MB
#   - ncurses                6.5  h59595ed_0          conda-forge      887kB
#   - libzlib             1.2.13  h4ab18f5_6          conda-forge       62kB
#   - libgcc-ng           13.2.0  h77fa898_7          conda-forge      776kB
#   - _openmp_mutex          4.5  2_gnu               conda-forge       24kB
#   - libgomp             13.2.0  h77fa898_7          conda-forge      422kB
#   - _libgcc_mutex          0.1  conda_forge         conda-forge        3kB
#
#   Summary:
#
#   Remove: 24 packages
#
#   Total download: 0 B
#
# ----------------------------------------------------------------------------
#
#
#
# Transaction starting
# Unlinking pip-24.0-pyhd8ed1ab_0
# Unlinking python-3.11.0-h7a1cb2a_3
# Unlinking setuptools-70.0.0-pyhd8ed1ab_0
# Unlinking wheel-0.43.0-pyhd8ed1ab_1
# Unlinking zlib-1.2.13-h4ab18f5_6
# Unlinking xz-5.4.2-h5eee18b_0
# Unlinking tzdata-2024a-h0c530f3_0
# Unlinking tk-8.6.13-noxft_h4845f30_101
# Unlinking sqlite-3.45.3-h2c6b66d_0
# Unlinking openssl-1.1.1w-h7f8727e_0
# Unlinking libuuid-1.41.5-h5eee18b_0
# Unlinking libffi-3.4.4-h6a678d5_0
# Unlinking ld_impl_linux-64-2.40-hf3520f5_2
# Unlinking bzip2-1.0.8-hd590300_5
# Unlinking readline-8.2-h8228510_1
# Unlinking libsqlite-3.45.3-h2797004_0
# Unlinking ca-certificates-2024.6.2-hbcca054_0
# Unlinking libstdcxx-ng-12.3.0-hc0a3c3a_7
# Unlinking ncurses-6.5-h59595ed_0
# Unlinking libzlib-1.2.13-h4ab18f5_6
# Unlinking libgcc-ng-13.2.0-h77fa898_7
# Unlinking _openmp_mutex-4.5-2_gnu
# Unlinking libgomp-13.2.0-h77fa898_7
# Unlinking _libgcc_mutex-0.1-conda_forge
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate D:\git\RBM\example\.CondaPkg\env
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -p D:\git\RBM\example\.CondaPkg\env mycommand
#     CondaPkg Creating environment
#              │ C:\Users\pedroripper\.julia\artifacts\cba433181fa6470b206db49415f1b7593a9d25ff\bin\micromamba.exe
#              │ -r C:\Users\pedroripper\.julia\scratchspaces\0b3b1443-0f03-428d-bdfb-f27f9c1191ea\root
#              │ create
#              │ -y
#              │ -p D:\git\RBM\example\.CondaPkg\env
#              │ --override-channels
#              │ --no-channel-priority
#              │ pip[version='>=22.0.0']
#              │ python[version='>=3.7,<=3.11']
#              │ python[version='>=3.8,<4',channel='anaconda']
#              │ -c anaconda
#              └ -c conda-forge
# Transaction
#
#   Prefix: D:\git\RBM\example\.CondaPkg\env
#
#   Updating specs:
#
#    - pip[version='>=22.0.0']
#    - python[version='>=3.7,<=3.11']
#    - anaconda::python[version='>=3.8,<4']
#
#
#   Package                 Version  Build         Channel           Size
# -------------------------------------------------------------------------
#   Install:
# -------------------------------------------------------------------------
#
#   + tzdata                  2024a  h0c530f3_0    conda-forge     Cached
#   + ucrt             10.0.22621.0  h57928b3_0    conda-forge     Cached
#   + ca-certificates      2024.6.2  h56e8100_0    conda-forge     Cached
#   + vc14_runtime      14.40.33810  ha82c5b3_20   conda-forge     Cached
#   + vc                       14.3  h8a93ad2_20   conda-forge     Cached
#   + vs2015_runtime    14.40.33810  h3bf8584_20   conda-forge     Cached
#   + libzlib                1.2.13  h2466b09_6    conda-forge     Cached
#   + tk                     8.6.13  h5226925_1    conda-forge     Cached
#   + libsqlite              3.46.0  h2466b09_0    conda-forge      877kB
#   + bzip2                   1.0.8  hcfcfb64_5    conda-forge     Cached
#   + zlib                   1.2.13  h2466b09_6    conda-forge     Cached
#   + sqlite                 3.46.0  h2466b09_0    conda-forge      886kB
#   + openssl                1.1.1w  h2bbff1b_0    anaconda        Cached
#   + xz                      5.4.2  h8cc25b3_0    anaconda        Cached
#   + libffi                  3.4.4  hd77b12b_0    anaconda        Cached
#   + python                 3.11.0  h966fe2a_3    anaconda        Cached
#   + pip                      24.0  pyhd8ed1ab_0  conda-forge     Cached
#   + setuptools             70.0.0  pyhd8ed1ab_0  conda-forge     Cached
#   + wheel                  0.43.0  pyhd8ed1ab_1  conda-forge     Cached
#
#   Summary:
#
#   Install: 19 packages
#
#   Total download: 2MB
#
# -------------------------------------------------------------------------
#
#
#
# Transaction starting
# Linking tzdata-2024a-h0c530f3_0
# Linking ucrt-10.0.22621.0-h57928b3_0
# Linking ca-certificates-2024.6.2-h56e8100_0
# Linking vc14_runtime-14.40.33810-ha82c5b3_20
# Linking vc-14.3-h8a93ad2_20
# Linking vs2015_runtime-14.40.33810-h3bf8584_20
# Linking libzlib-1.2.13-h2466b09_6
# Linking tk-8.6.13-h5226925_1
# Linking libsqlite-3.46.0-h2466b09_0
# Linking bzip2-1.0.8-hcfcfb64_5
# Linking zlib-1.2.13-h2466b09_6
# Linking sqlite-3.46.0-h2466b09_0
# Linking openssl-1.1.1w-h2bbff1b_0
# Linking xz-5.4.2-h8cc25b3_0
# Linking libffi-3.4.4-hd77b12b_0
# Linking python-3.11.0-h966fe2a_3
# Linking pip-24.0-pyhd8ed1ab_0
# Linking setuptools-70.0.0-pyhd8ed1ab_0
# Linking wheel-0.43.0-pyhd8ed1ab_1
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate D:\git\RBM\example\.CondaPkg\env
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -p D:\git\RBM\example\.CondaPkg\env mycommand
#     CondaPkg Installing Pip packages
#              │ D:\git\RBM\example\.CondaPkg\env\Scripts\pip.exe
#              │ install
#              │ dwave-networkx ==0.8.14
#              │ dwave-ocean-sdk ==6.7.0
#              └ numpy >=1.20
# Collecting dwave-networkx==0.8.14
#   Using cached dwave_networkx-0.8.14-py3-none-any.whl.metadata (2.6 kB)
# Collecting dwave-ocean-sdk==6.7.0
#   Using cached dwave_ocean_sdk-6.7.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting numpy>=1.20
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ------------------------------------- 61.0/61.0 kB 250.2 kB/s eta 0:00:00
# Collecting networkx>=2.4 (from dwave-networkx==0.8.14)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting dimod>=0.10.8 (from dwave-networkx==0.8.14)
#   Using cached dimod-0.12.14-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
#   Using cached dimod-0.12.13-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting dwave-cloud-client==0.11.1 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_cloud_client-0.11.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting dwave-greedy==0.3.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_greedy-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting dwave-hybrid==0.6.10 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_hybrid-0.6.10-py3-none-any.whl.metadata (4.6 kB)
# Collecting dwave-inspector==0.4.3 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_inspector-0.4.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting dwave-neal==0.6.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_neal-0.6.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting dwave-preprocessing==0.6.4 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_preprocessing-0.6.4-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Collecting dwave-samplers==1.2.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_samplers-1.2.0-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting dwave-system==1.21.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_system-1.21.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dwave-tabu==0.5.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwave_tabu-0.5.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting dwavebinarycsp==0.2.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached dwavebinarycsp-0.2.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting minorminer==0.2.12 (from dwave-ocean-sdk==6.7.0)
#   Using cached minorminer-0.2.12-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting penaltymodel==1.0.2 (from dwave-ocean-sdk==6.7.0)
#   Using cached penaltymodel-1.0.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyqubo==1.4.0 (from dwave-ocean-sdk==6.7.0)
#   Using cached pyqubo-1.4.0-cp311-cp311-win_amd64.whl.metadata (7.5 kB)
# Collecting requests>=2.18 (from requests[socks]>=2.18->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic<3,>=2 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading pydantic-2.7.3-py3-none-any.whl.metadata (108 kB)
#      ----------------------------------- 109.0/109.0 kB 700.2 kB/s eta 0:00:00
# Collecting homebase>=1.0 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached homebase-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting click>=7.0 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pedroripper\appdata\roaming\python\python311\site-packages (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0) (2.9.0.post0)
# Collecting plucky>=0.4.3 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached plucky-0.4.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting diskcache>=5.2.1 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=19 in c:\users\pedroripper\appdata\roaming\python\python311\site-packages (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0) (24.0)
# Collecting werkzeug>=2.2 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\pedroripper\appdata\roaming\python\python311\site-packages (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0) (4.11.0)
# Collecting authlib<2,>=1.2 (from dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading Authlib-1.3.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting Flask>=2.2 (from dwave-inspector==0.4.3->dwave-ocean-sdk==6.7.0)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting networkx>=2.4 (from dwave-networkx==0.8.14)
#   Using cached networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting scipy>=1.7.3 (from dwave-system==1.21.0->dwave-ocean-sdk==6.7.0)
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      --------------------------------------- 60.6/60.6 kB 1.1 MB/s eta 0:00:00
# Collecting fasteners>=0.15 (from minorminer==0.2.12->dwave-ocean-sdk==6.7.0)
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting rectangle-packer>=2.0.1 (from minorminer==0.2.12->dwave-ocean-sdk==6.7.0)
#   Using cached rectangle_packer-2.0.2-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting Deprecated>=1.2.12 (from pyqubo==1.4.0->dwave-ocean-sdk==6.7.0)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: six>=1.15.0 in c:\users\pedroripper\appdata\roaming\python\python311\site-packages (from pyqubo==1.4.0->dwave-ocean-sdk==6.7.0) (1.16.0)
# Collecting cryptography (from authlib<2,>=1.2->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: colorama in c:\users\pedroripper\appdata\roaming\python\python311\site-packages (from click>=7.0->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0) (0.4.6)
# Collecting wrapt<2,>=1.10 (from Deprecated>=1.2.12->pyqubo==1.4.0->dwave-ocean-sdk==6.7.0)
#   Using cached wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting Jinja2>=3.1.2 (from Flask>=2.2->dwave-inspector==0.4.3->dwave-ocean-sdk==6.7.0)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.1.2 (from Flask>=2.2->dwave-inspector==0.4.3->dwave-ocean-sdk==6.7.0)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.6.2 (from Flask>=2.2->dwave-inspector==0.4.3->dwave-ocean-sdk==6.7.0)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic<3,>=2->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading pydantic_core-2.18.4-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Downloading certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]>=2.18->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=2.2->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting cffi>=1.12 (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.11.1->dwave-ocean-sdk==6.7.0)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached dwave_networkx-0.8.14-py3-none-any.whl (102 kB)
# Using cached dwave_ocean_sdk-6.7.0-py3-none-any.whl (8.4 kB)
# Using cached dimod-0.12.13-cp311-cp311-win_amd64.whl (5.1 MB)
# Using cached dwave_cloud_client-0.11.1-py3-none-any.whl (138 kB)
# Using cached dwave_greedy-0.3.0-py3-none-any.whl (10 kB)
# Using cached dwave_hybrid-0.6.10-py3-none-any.whl (74 kB)
# Using cached dwave_inspector-0.4.3-py3-none-any.whl (31 kB)
# Using cached dwave_neal-0.6.0-py3-none-any.whl (8.7 kB)
# Using cached dwave_preprocessing-0.6.4-cp311-cp311-win_amd64.whl (817 kB)
# Using cached dwave_samplers-1.2.0-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached dwave_system-1.21.0-py3-none-any.whl (103 kB)
# Using cached dwave_tabu-0.5.0-py3-none-any.whl (9.2 kB)
# Using cached dwavebinarycsp-0.2.0-py3-none-any.whl (35 kB)
# Using cached minorminer-0.2.12-cp311-cp311-win_amd64.whl (960 kB)
# Using cached penaltymodel-1.0.2-py3-none-any.whl (36 kB)
# Using cached pyqubo-1.4.0-cp311-cp311-win_amd64.whl (388 kB)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 15.8/15.8 MB 3.4 MB/s eta 0:00:00
# Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Downloading Authlib-1.3.1-py2.py3-none-any.whl (223 kB)
#    --------------------------------------- 223.8/223.8 kB 4.6 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached homebase-1.0.1-py2.py3-none-any.whl (11 kB)
# Using cached plucky-0.4.3-py2.py3-none-any.whl (10 kB)
# Downloading pydantic-2.7.3-py3-none-any.whl (409 kB)
#    --------------------------------------- 409.6/409.6 kB 3.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 1.9/1.9 MB 3.0 MB/s eta 0:00:00
# Using cached rectangle_packer-2.0.2-cp311-cp311-win_amd64.whl (58 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 46.2/46.2 MB 3.5 MB/s eta 0:00:00
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#    --------------------------------------- 164.4/164.4 kB 3.3 MB/s eta 0:00:00
# Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached wrapt-1.16.0-cp311-cp311-win_amd64.whl (37 kB)
# Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 2.9/2.9 MB 2.4 MB/s eta 0:00:00
# Using cached cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: rectangle-packer, plucky, homebase, wrapt, urllib3, PySocks, pydantic-core, pycparser, numpy, networkx, MarkupSafe, itsdangerous, idna, fasteners, diskcache, click, charset-normalizer, certifi, blinker, annotated-types, werkzeug, scipy, requests, pydantic, Jinja2, dimod, Deprecated, cffi, penaltymodel, Flask, dwave-samplers, dwave-preprocessing, dwave-networkx, cryptography, minorminer, dwavebinarycsp, dwave-tabu, dwave-neal, dwave-greedy, authlib, pyqubo, dwave-cloud-client, dwave-system, dwave-inspector, dwave-hybrid, dwave-ocean-sdk
# Successfully installed Deprecated-1.2.14 Flask-3.0.3 Jinja2-3.1.4 MarkupSafe-2.1.5 PySocks-1.7.1 annotated-types-0.7.0 authlib-1.3.1 blinker-1.8.2 certifi-2024.6.2 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 cryptography-42.0.8 dimod-0.12.13 diskcache-5.6.3 dwave-cloud-client-0.11.1 dwave-greedy-0.3.0 dwave-hybrid-0.6.10 dwave-inspector-0.4.3 dwave-neal-0.6.0 dwave-networkx-0.8.14 dwave-ocean-sdk-6.7.0 dwave-preprocessing-0.6.4 dwave-samplers-1.2.0 dwave-system-1.21.0 dwave-tabu-0.5.0 dwavebinarycsp-0.2.0 fasteners-0.19 homebase-1.0.1 idna-3.7 itsdangerous-2.2.0 minorminer-0.2.12 networkx-2.8.8 numpy-1.26.4 penaltymodel-1.0.2 plucky-0.4.3 pycparser-2.22 pydantic-2.7.3 pydantic-core-2.18.4 pyqubo-1.4.0 rectangle-packer-2.0.2 requests-2.32.3 scipy-1.13.1 urllib3-2.2.1 werkzeug-3.0.3 wrapt-1.16.0
# ┌ Warning: The 'DWAVE_API_TOKEN' environment variable is not defined.
# │ If you want to use D-Wave's cloud services, please make sure that another access method is available.
# │
# │ For more information visit:
# │     https://docs.ocean.dwavesys.com/en/stable/overview/sapi.html
# └ @ DWave C:\Users\pedroripper\.julia\packages\DWave\i51VN\src\DWave.jl:24

# %%
MOI = QARBoM.QUBO.ToQUBO.MOI
# Out:
# MathOptInterface

# %%
df = DataFrame(CSV.File(raw"./converted_bool_only.csv"))

x_train = Vector{Vector{Int}}()

for row in eachrow(df)
    push!(x_train, collect(row))
end

# %%
learning_rates = [i for i in range(0.001, 0.01, 10)]
# Out:
# 10-element Vector{Float64}:
#  0.001
#  0.002
#  0.003
#  0.004
#  0.005
#  0.006
#  0.007
#  0.008
#  0.009
#  0.01

# %%
W = rand(22,10)
# Out:
# 22×10 Matrix{Float64}:
#  0.256366  0.697361   0.873445    …  0.754165   0.349081   0.817954
#  0.948938  0.297045   0.606345       0.857629   0.576317   0.5632
#  0.581884  0.130355   0.453745       0.516062   0.114246   0.353833
#  0.800552  0.711861   0.982529       0.479625   0.664315   0.151093
#  0.975268  0.511576   0.209603       0.143531   0.722907   0.677978
#  0.559571  0.783223   0.550131    …  0.08045    0.530796   0.935712
#  0.0304    0.697973   0.0876831      0.771087   0.896123   0.37359
#  0.189684  0.227271   0.469226       0.0560455  0.537495   0.619708
#  0.400364  0.61444    0.968505       0.263125   0.135446   0.413619
#  0.248108  0.265857   0.0296809      0.687388   0.66067    0.544337
#  0.74451   0.333175   0.00851113  …  0.721305   0.441684   0.669082
#  0.893835  0.0902368  0.427539       0.901145   0.621691   0.781424
#  0.313696  0.0723903  0.601486       0.820114   0.0481769  0.844574
#  0.870608  0.990187   0.289307       0.484496   0.342724   0.903167
#  0.756874  0.768093   0.724022       0.501624   0.964873   0.956145
#  0.439185  0.645228   0.688101    …  0.790639   0.5373     0.37967
#  0.439533  0.373245   0.502901       0.261825   0.423943   0.396765
#  0.638933  0.960608   0.413518       0.469602   0.830955   0.453188
#  0.4589    0.10037    0.097195       0.263301   0.75751    0.503759
#  0.556452  0.0932629  0.136957       0.29102    0.980611   0.615434
#  0.728375  0.583373   0.556497    …  0.131384   0.387393   0.716
#  0.625182  0.994134   0.0422049      0.699341   0.581079   0.192426

# %%
all_mse = []
# Out:
# Any[]

# %%
for learning_rate in learning_rates
    rbm = QARBoM.QUBORBM(22,10, DWave.Neal.Optimizer)
    MOI.set(rbm.model, MOI.RawOptimizerAttribute("num_reads"), 250)
    MOI.set(rbm.model, MOI.RawOptimizerAttribute("num_sweeps"), 10)

    println()
    println("Learning rate $(learning_rate)") 
    println()

    mse = QARBoM.train_persistent_qubo(rbm, x_train[1:10000];n_samples = 1, batch_size = 10, n_epochs = 50, 
        learning_rate = [learning_rate for i in 1:50])

    push!(all_mse, mse)
end
# Out:
# Learning rate 0.001
#
# Setting mini-batches
# Starting training
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     1 |    4.4267 |        0.0187 |      20.2309 |        4.1851 |   24.4347 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     2 |    2.7332 |        0.0202 |      14.5805 |        2.6467 |   41.6822 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     3 |    2.3978 |        0.0229 |      12.5826 |        2.5777 |   56.8653 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     4 |    2.5276 |        0.0170 |      11.5445 |        2.1688 |   70.5957 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     5 |    2.6948 |        0.0171 |      11.2638 |        2.1704 |   84.0470 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     6 |    2.5419 |        0.0169 |      11.5410 |        2.0096 |   97.6145 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     7 |    2.4964 |        0.2030 |      13.9854 |        2.9222 |  114.7251 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     8 |    2.4198 |        0.0187 |      14.3706 |        2.5368 |  131.6511 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     9 |    2.4016 |        0.0174 |      12.1446 |        2.2978 |  146.1109 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    10 |    2.2868 |        0.0179 |      13.2265 |        2.5044 |  161.8597 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    11 |    2.2636 |        0.0180 |      13.8989 |        2.5149 |  178.2915 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    12 |    2.2382 |        0.0185 |      13.0098 |        3.2104 |  194.5301 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    13 |    2.2413 |        0.0201 |      12.9415 |        2.2117 |  209.7035 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |
|
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    39 |    2.3782 |        0.1226 |      11.1999 |        1.9333 |  430.8810 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    40 |    2.3861 |        0.0137 |       9.3278 |        1.7318 |  441.9543 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    41 |    2.3928 |        0.1197 |       9.3227 |        1.6948 |  453.0915 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    42 |    2.4790 |        0.0129 |       9.2563 |        1.6202 |  463.9809 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    43 |    2.5516 |        0.0142 |      10.4862 |        1.8863 |  476.3676 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    44 |    2.5742 |        0.0128 |       8.8362 |        1.7386 |  486.9552 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    45 |    2.5911 |        0.0128 |       8.7009 |        1.7325 |  497.4015 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    46 |    2.6160 |        0.0127 |       9.2714 |        1.5439 |  508.2295 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    47 |    2.6023 |        0.0124 |       8.2351 |        1.5767 |  518.0537 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    48 |    2.5881 |        0.0123 |       8.2256 |        1.4713 |  527.7629 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    49 |    2.5549 |        0.0125 |       8.0717 |        1.5697 |  537.4169 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    50 |    2.4998 |        0.0125 |       8.0945 |        1.5498 |  547.0737 |
# |------------------------------------------------------------------------------|
# Finished training after 50 epochs.
# Total time spent sampling: 1.5908868312835693
# Total time spent in Quantum sampling: 461.880322933197
# Total time spent updating parameters: 83.60244250297546
# Total time spent training: 547.073652267456
#
# Learning rate 0.003
#
# Setting mini-batches
# Starting training
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     1 |    3.5484 |        0.0902 |       9.1729 |        1.4067 |   10.6698 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     2 |    2.5706 |        0.0126 |       8.3126 |        1.4696 |   20.4646 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     3 |    2.5532 |        0.0126 |       7.7920 |        1.8375 |   30.1067 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     4 |    2.5627 |        0.0123 |       8.3883 |        1.5555 |   40.0628 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     5 |    2.5051 |        0.0123 |       8.3911 |        1.4635 |   49.9297 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     6 |    2.5378 |        0.1055 |       8.2845 |        1.6765 |   59.9962 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     7 |    2.5564 |        0.0129 |       8.6626 |        1.6061 |   70.2778 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     8 |    2.6445 |        0.0126 |       8.3312 |        1.4742 |   80.0958 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     9 |    2.7070 |        0.0167 |      11.8419 |        2.0152 |   93.9696 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    10 |    2.7255 |        0.0159 |      11.4399 |        1.9100 |  107.3353 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    11 |    2.8331 |        0.1298 |      10.1509 |        1.7877 |  119.4038 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    12 |    2.9311 |        0.0146 |      11.5836 |        1.8864 |  132.8884 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    13 |    2.9205 |        0.0942 |       9.9317 |        1.7608 |  144.6751 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    14 |    2.9468 |        0.1147 |      11.0191 |        1.6780 |  157.4869 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    15 |    2.9496 |        0.0135 |      10.5246 |        1.5569 |  169.5819 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    16 |    2.9388 |        0.0130 |       9.7914 |        1.5010 |  180.8874 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    17 |    3.0039 |        0.0135 |       9.2217 |        1.6074 |  191.7300 |
# ...
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    12 |    3.8551 |        0.0123 |       8.2221 |        1.5967 |  119.2425 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    13 |    4.3241 |        0.0124 |       8.6113 |        1.3995 |  129.2658 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    14 |    3.9272 |        0.0127 |       8.8059 |        1.4429 |  139.5272 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    15 |    4.2305 |        0.0123 |       8.5800 |        1.5793 |  149.6988 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    16 |    4.4694 |        0.0121 |       8.5181 |        1.5029 |  159.7319 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    17 |    4.5291 |        0.0122 |       8.3428 |        1.5718 |  169.6588 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    18 |    4.9794 |        0.0124 |       8.4923 |        1.4899 |  179.6535 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    19 |    5.2222 |        0.0127 |       8.1611 |        1.4786 |  189.3059 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    20 |    5.2424 |        0.0124 |       8.2163 |        1.5876 |  199.1221 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    21 |    5.2310 |        0.0124 |       8.2741 |        1.5925 |  209.0011 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    22 |    5.2147 |        0.0127 |       8.2988 |        1.7196 |  219.0323 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    23 |    5.1956 |        0.0129 |       8.4534 |        1.3843 |  228.8828 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    24 |    5.1764 |        0.1121 |       7.8889 |        1.8996 |  238.7834 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    25 |    5.1501 |        0.1139 |       8.2671 |        1.4813 |  248.6457 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    26 |    5.1295 |        0.1132 |       8.2384 |        1.6064 |  258.6038 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    27 |    5.1072 |        0.0124 |       8.2074 |        1.6729 |  268.4966 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    28 |    5.0880 |        0.0126 |       8.4402 |        1.3961 |  278.3454 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    29 |    5.0603 |        0.1120 |       8.2953 |        1.4918 |  288.2446 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    30 |    5.0301 |        0.0124 |       8.0920 |        1.4957 |  297.8446 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    31 |    5.0072 |        0.1100 |       8.1050 |        1.6971 |  307.7567 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    32 |    4.9791 |        0.0125 |       8.3100 |        1.4831 |  317.5623 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    33 |    4.9637 |        0.0127 |       8.5951 |        1.3894 |  327.5596 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    34 |    4.9499 |        0.0126 |       8.4030 |        1.6215 |  337.5966 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    35 |    4.9339 |        0.0124 |       8.5089 |        1.4879 |  347.6058 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    36 |    4.9218 |        0.0126 |       8.2989 |        1.4927 |  357.4100 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    37 |    4.9190 |        0.1116 |       8.2903 |        1.6183 |  367.4302 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    38 |    4.9157 |        0.0126 |       8.4933 |        1.6241 |  377.5603 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    39 |    4.9162 |        0.0126 |       8.4511 |        1.6182 |  387.6422 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    40 |    4.9131 |        0.0128 |       8.6926 |        1.6563 |  398.0038 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    41 |    4.9113 |        0.0128 |       8.5945 |        1.6632 |  408.2742 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    42 |    4.9089 |        0.0125 |       8.1612 |        1.7004 |  418.1483 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    43 |    4.9075 |        0.0126 |       8.4137 |        1.3873 |  427.9619 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    44 |    4.9063 |        0.1137 |       8.2262 |        1.6060 |  437.9078 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    45 |    4.9033 |        0.0125 |       8.3117 |        1.5978 |  447.8298 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    46 |    4.9030 |        0.0128 |       8.3951 |        1.5048 |  457.7426 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    47 |    4.9000 |        0.0124 |       8.2155 |        1.6066 |  467.5771 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    48 |    4.8968 |        0.0127 |       8.5796 |        1.6413 |  477.8107 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    49 |    4.8954 |        0.0127 |       8.1750 |        1.7051 |  487.7034 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    50 |    4.8936 |        0.2115 |       8.1565 |        1.4911 |  497.5625 |
# |------------------------------------------------------------------------------|
# Finished training after 50 epochs.
# Total time spent sampling: 1.6162331104278564
# Total time spent in Quantum sampling: 418.1242399215698
# Total time spent updating parameters: 77.82200384140015
# Total time spent training: 497.5624768733978

# %%
using Plots

# %%
plot(range(1,50), [all_mse],label = permutedims(["ϵ = $lr" for lr in learning_rates]), linewidth=2)
# plot(range(1,50, length = 50), all_mse[2],label = "ϵ = 0.002")
xlabel!("Epoch")
ylabel!("Mean Squared Error")
plot!(legend=:outerbottom, legendcolumns=5)
savefig("plot_1.pdf")
# Out:
# "/Users/pripper/Documents/GitHub/RBM/example/plot_1.pdf"

# %%
df = DataFrame()
i = 1
for lr in learning_rates
    df[!,"$lr"] =  all_mse[i]
    i += 1
end

# %%
CSV.write("mse_1.csv", df)
# Out:
# "mse_1.csv"

# %%
learning_rates_2 = [i for i in range(0.0001, 0.001, 10)]
# Out:
# 10-element Vector{Float64}:
#  0.0001
#  0.0002
#  0.0003
#  0.0004
#  0.0005
#  0.0006
#  0.0007
#  0.0008
#  0.0009
#  0.001

# %%
all_mse_2 = []
# Out:
# Any[]

# %%
for learning_rate in learning_rates_2
    rbm = QARBoM.QUBORBM(22,10, DWave.Neal.Optimizer)
    MOI.set(rbm.model, MOI.RawOptimizerAttribute("num_reads"), 250)
    MOI.set(rbm.model, MOI.RawOptimizerAttribute("num_sweeps"), 10)

    println()
    println("Learning rate $(learning_rate)") 
    println()

    mse = QARBoM.train_persistent_qubo(rbm, x_train[1:10000];n_samples = 1, batch_size = 10, n_epochs = 50, 
        learning_rate = [learning_rate for i in 1:50])

    push!(all_mse_2, mse)
end
# Out:
# Learning rate 0.0001
#
# Setting mini-batches
# Starting training
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     1 |    6.5573 |        0.0207 |       9.9148 |        1.6801 |   11.6156 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     2 |    5.7656 |        0.1100 |       9.1626 |        1.6117 |   22.4998 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     3 |    5.1021 |        0.0129 |      12.5204 |        2.2805 |   37.3135 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     4 |    4.5626 |        0.0123 |      10.2741 |        1.8626 |   49.4625 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     5 |    4.1468 |        0.0122 |       9.9319 |        1.8821 |   61.2887 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     6 |    3.8450 |        0.0126 |      10.5776 |        1.5839 |   73.4628 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     7 |    3.6249 |        0.0121 |       9.7445 |        1.7506 |   84.9700 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     8 |    3.4564 |        0.0964 |      10.0839 |        1.4863 |   96.6366 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     9 |    3.3308 |        0.0121 |       9.7545 |        1.6757 |  108.0790 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    10 |    3.2366 |        0.0119 |       9.9962 |        1.4728 |  119.5599 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    11 |    3.1615 |        0.0120 |       9.5727 |        1.5847 |  130.7292 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    12 |    3.1026 |        0.0121 |       9.4491 |        1.6657 |  141.8562 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    13 |    3.0562 |        0.0125 |       9.5031 |        1.4881 |  152.8599 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    14 |    3.0208 |        0.0123 |       9.1071 |        1.8877 |  163.8670 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    15 |    2.9930 |        0.0121 |       8.9537 |        1.6925 |  174.5253 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    16 |    2.9669 |        0.0122 |       9.1154 |        1.7041 |  185.3569 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    17 |    2.9406 |        0.0123 |       9.0240 |        1.6099 |  196.0031 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    18 |    2.9201 |        0.0123 |       9.0829 |        1.7610 |  206.8592 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    19 |    2.9118 |        0.0123 |       8.9336 |        1.4847 |  217.2897 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    20 |    2.8993 |        0.0120 |       8.8897 |        1.6051 |  227.7965 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    21 |    2.8788 |        0.0124 |       8.7492 |        1.7171 |  238.2752 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    22 |    2.8644 |        0.0125 |       8.8542 |        2.0489 |  249.1909 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    23 |    2.8383 |        0.0125 |       9.1454 |        1.5912 |  259.9399 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    24 |    2.8336 |        0.0130 |       9.3367 |        1.7231 |  271.0127 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    25 |    2.8420 |        0.0126 |       8.9704 |        1.8047 |  281.8004 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    26 |    2.8230 |        0.0125 |       8.7148 |        1.6568 |  292.1844 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    27 |    2.7626 |        0.0123 |       8.4902 |        1.6259 |  302.3128 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    28 |    2.7067 |        0.0124 |       8.2986 |        1.7818 |  312.4056 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    29 |    2.6562 |        0.0123 |       8.4617 |        1.6871 |  322.5667 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    30 |    2.6044 |        0.0122 |       8.4360 |        1.5777 |  332.5926 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    31 |    2.5521 |        0.0124 |       8.8293 |        1.4933 |  342.9277 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    32 |    2.5087 |        0.0122 |       8.4670 |        1.6835 |  353.0904 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    33 |    2.4774 |        0.0124 |       8.6013 |        1.5743 |  363.2785 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    34 |    2.4499 |        0.0122 |       8.6635 |        1.5777 |  373.5318 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    35 |    2.4196 |        0.0122 |       8.3849 |        1.7606 |  383.6895 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    36 |    2.3921 |        0.1068 |       8.7086 |        1.5998 |  394.1047 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    37 |    2.3771 |        0.0125 |       8.1751 |        2.0723 |  404.3646 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    38 |    2.3607 |        0.2019 |       8.5266 |        1.4790 |  414.5721 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    39 |    2.3468 |        0.0122 |       8.8812 |        1.5471 |  425.0126 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    40 |    2.3365 |        0.1127 |       8.3115 |        1.8724 |  435.3093 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    41 |    2.3307 |        0.0124 |       8.9359 |        1.4807 |  445.7382 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    42 |    2.3299 |        0.0123 |       8.2562 |        1.9614 |  455.9682 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    43 |    2.3273 |        0.0123 |       8.8129 |        1.5790 |  466.3724 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    44 |    2.3247 |        0.0124 |       8.6406 |        1.7221 |  476.7474 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    45 |    2.3287 |        0.0123 |       8.4949 |        1.8023 |  487.0570 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    46 |    2.3334 |        0.0121 |       8.2257 |        1.8739 |  497.1687 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    47 |    2.3312 |        0.0122 |       8.4340 |        1.6742 |  507.2891 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    48 |    2.3300 |        0.0122 |       8.5122 |        1.5713 |  517.3848 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    49 |    2.3297 |        0.0124 |       8.4037 |        1.6880 |  527.4889 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    50 |    2.3338 |        0.0123 |       8.2809 |        1.8107 |  537.5927 |
# |------------------------------------------------------------------------------|
# Finished training after 50 epochs.
# Total time spent sampling: 1.1902484893798828
# Total time spent in Quantum sampling: 451.5948922634125
# Total time spent updating parameters: 84.80755972862244
# Total time spent training: 537.5927004814148
#
# Learning rate 0.0002
#
# Setting mini-batches
# Starting training
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     1 |    7.2337 |        0.0123 |       8.4464 |        1.8621 |   10.3209 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     2 |    5.7280 |        0.0125 |       8.5271 |        1.9126 |   20.7730 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     3 |    4.5938 |        0.0122 |       9.5857 |        1.4999 |   31.8708 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     4 |    3.7762 |        0.0123 |       9.7936 |        1.5789 |   43.2557 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     5 |    3.2364 |        0.0122 |      10.3283 |        1.5753 |   55.1714 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     6 |    2.8916 |        0.0187 |      13.5858 |        2.0189 |   70.7948 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     7 |    2.6614 |        0.0298 |      13.6002 |        2.0961 |   86.5210 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     8 |    2.5164 |        0.0132 |      11.4629 |        1.8261 |   99.8232 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |     9 |    2.4188 |        0.0128 |      11.2243 |        1.7390 |  112.7993 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    10 |    2.3611 |        0.0126 |      11.0260 |        2.0758 |  125.9138 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |
|
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    30 |    2.1827 |        0.0118 |       8.4075 |        1.6395 |  304.0563 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    31 |    2.1737 |        0.0117 |       8.4169 |        1.6922 |  314.1771 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    32 |    2.2352 |        0.0123 |       9.0850 |        1.7591 |  325.0335 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    33 |    2.3254 |        0.0122 |       8.5128 |        1.8099 |  335.3685 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    34 |    2.3125 |        0.0121 |       8.8720 |        1.4924 |  345.7451 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    35 |    2.2307 |        0.0124 |       9.9096 |        1.6821 |  357.3491 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    36 |    2.2114 |        0.1137 |       8.8090 |        1.7795 |  368.0514 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    37 |    2.2295 |        0.0119 |       8.9269 |        1.6748 |  378.6650 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    38 |    2.2573 |        0.0122 |       8.8845 |        1.6091 |  389.1709 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    39 |    2.2372 |        0.0120 |       8.6908 |        1.7646 |  399.6383 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    40 |    2.2228 |        0.0123 |       8.5230 |        1.7007 |  409.8742 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    41 |    2.2173 |        0.0119 |       8.5667 |        1.5429 |  419.9957 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    42 |    2.2431 |        0.0119 |       8.5558 |        1.5519 |  430.1153 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    43 |    2.2685 |        0.0117 |       8.4922 |        1.6409 |  440.2600 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    44 |    2.3292 |        0.0117 |       8.1578 |        1.8354 |  450.2650 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    45 |    2.3774 |        0.0118 |       8.2538 |        1.6376 |  460.1681 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    46 |    2.3431 |        0.1100 |       8.5556 |        1.4479 |  470.2816 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    47 |    2.3881 |        0.1135 |       8.0372 |        1.6452 |  480.0775 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    48 |    2.4689 |        0.0120 |       8.3237 |        1.5363 |  489.9495 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    49 |    2.5717 |        0.0119 |       8.2747 |        1.6469 |  499.8830 |
# |------------------------------------------------------------------------------|
# |------------------------------------------------------------------------------|
# | Epoch |    MSE    | Time (Sample) | Time (Qsamp) | Time (Update) | Total     |
# |------------------------------------------------------------------------------|
# |    50 |    2.6159 |        0.0118 |       8.2063 |        1.6423 |  509.7434 |
# |------------------------------------------------------------------------------|
# Finished training after 50 epochs.
# Total time spent sampling: 1.0945558547973633
# Total time spent in Quantum sampling: 427.55376529693604
# Total time spent updating parameters: 81.0950620174408
# Total time spent training: 509.7433831691742

# %%
plot(range(1,50), [all_mse_2],label = permutedims(["ϵ = $lr" for lr in learning_rates_2]), linewidth=2)
# plot(range(1,50, length = 50), all_mse[2],label = "ϵ = 0.002")
theme(:wong)


lens!([45, 50], [2, 3], inset = (1, bbox(0.5, 0.0, 0.4, 0.4)), subplot=2)


xlabel!("Epoch", subplot =1)
ylabel!("Mean Squared Error", subplot =1 )

plot!(legend=:outerbottom, legendcolumns=5)

savefig("plot_2.pdf")
# Out:
# "/Users/pripper/Documents/GitHub/RBM/example/plot_2.pdf"

# %%
df_2 = DataFrame()
i = 1
for lr in learning_rates_2
    df_2[!,"$lr"] =  all_mse_2[i]
    i += 1
end

# %%
df_2
# Out:
# 50×10 DataFrame
#  Row │ 0.0001   0.0002   0.0003   0.0004   0.0005   0.0006   0.0007   0.0008   ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │
⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮     ⋱
#   41 │ 2.33066  2.21058  2.24156  2.06609  2.58673  2.1794   2.33616  2.83617
#   42 │ 2.32986  2.18371  2.19475  2.08784  2.60203  2.18282  2.42214  2.80669  ⋯
#   43 │ 2.32728  2.1466   2.17432  2.11999  2.62157  2.18739  2.4862   2.75211
#   44 │ 2.32468  2.11096  2.18262  2.16991  2.64116  2.19893  2.50039  2.77238
#   45 │ 2.32874  2.09464  2.18765  2.20678  2.64816  2.21939  2.4566   2.81481
#   46 │ 2.33342  2.09421  2.17212  2.20876  2.65099  2.24189  2.44419  2.82247  ⋯
#   47 │ 2.33122  2.08563  2.15713  2.17358  2.66425  2.26392  2.42579  2.81361
#   48 │ 2.32997  2.0761   2.14732  2.15662  2.67922  2.28337  2.373    2.81222
#   49 │ 2.32969  2.06582  2.14745  2.13126  2.69514  2.30841  2.37994  2.85439
#   50 │ 2.33375  2.05951  2.15389  2.11989  2.70693  2.32795  2.399    2.83441  ⋯
#                                                    2 columns and 29 rows omitted

# %%
# df_to_plot = select!(df_loaded, Not(["0.0005", "0.0007", "0.0008", "0.0009", "0.001"]))
df_to_plot = select!(df_loaded, Not(["0.0002", "0.0003", "0.0004", "0.0006", "0.0007", "0.0008", "0.001"]))
# Out:
# 50×3 DataFrame
#  Row │ 0.0001   0.0005   0.0009
#      │ Float64  Float64  Float64
# ─────┼───────────────────────────
#    1 │ 6.55728  4.67853  4.89483
#    2 │ 5.76565  3.27853  2.64878
#    3 │ 5.10207  2.76367  2.32022
#    4 │ 4.56265  2.55112  2.35124
#    5 │ 4.1468   2.48381  2.37845
#    6 │ 3.84501  2.45722  2.34842
#    7 │ 3.62493  2.45559  2.31414
#    8 │ 3.45643  2.45752  2.41274
#    9 │ 3.33077  2.49834  2.44691
#   10 │ 3.23661  2.55973  2.36536
#   11 │ 3.16149  2.6181   2.37537
#   ⋮  │    ⋮        ⋮        ⋮
#   41 │ 2.33066  2.58673  2.81254
#   42 │ 2.32986  2.60203  2.81757
#   43 │ 2.32728  2.62157  2.80152
#   44 │ 2.32468  2.64116  2.78725
#   45 │ 2.32874  2.64816  2.80765
#   46 │ 2.33342  2.65099  2.83049
#   47 │ 2.33122  2.66425  2.85884
#   48 │ 2.32997  2.67922  2.89295
#   49 │ 2.32969  2.69514  2.92519
#   50 │ 2.33375  2.70693  2.96655
#                   29 rows omitted

# %%
plot(Matrix(df_to_plot), labels=permutedims(string.("ϵ = " ,names(df_to_plot))), linewidth=2, botton_margin=0, right_margin = 3Plots.mm)
# plot(range(1,50, length = 50), all_mse[2],label = "ϵ = 0.002")
theme(:wong)


lens!([45, 50], [2, 3], inset = (1, bbox(0.5, 0.0, 0.4, 0.4)), subplot=2)


xlabel!("Epoch", subplot =1)
ylabel!("Mean Squared Error", subplot =1 )

plot!(legend=:outerbottom, legendcolumns=3)

savefig("errors.pdf")
# Out:
# "D:\\git\\RBM\\example\\errors.pdf"
